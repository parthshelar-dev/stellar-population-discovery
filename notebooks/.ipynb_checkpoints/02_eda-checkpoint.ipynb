# %%
import pandas as pd

df = pd.read_csv('../data/gaia_raw.csv')

print("Shape:", df.shape)
print("\nColumn Names:\n", df.columns.tolist())
print("\nNull Values:\n", df.isnull().sum())
print("\nBasic Stats:\n", df.describe())
# Out:
# Shape: (50000, 11)
#
# Column Names:
#  ['SOURCE_ID', 'ra', 'dec', 'parallax', 'parallax_error', 'pmra', 'pmdec', 'phot_g_mean_mag', 'bp_rp', 'radial_velocity', 'teff_gspphot']
#
# Null Values:
#  SOURCE_ID              0
# ra                     0
# dec                    0
# parallax               0
# parallax_error         0
# pmra                   0
# pmdec                  0
# phot_g_mean_mag        0
# bp_rp                  0
# radial_velocity    34505
# teff_gspphot        4102
# dtype: int64
#
# Basic Stats:
#            SOURCE_ID            ra           dec      parallax  parallax_error  \
# count  5.000000e+04  50000.000000  50000.000000  50000.000000    50000.000000
# mean   1.551643e+17     54.505261     39.904742      1.471146        0.058614
# std    2.386196e+16     17.540135      3.414259      1.475581        0.054986
# min    1.373330e+17     40.799767     35.280940      0.127327        0.010626
# ...
